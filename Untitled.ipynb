# %%
import cv2

# %%
# read an image 

img = cv2.imread("a.jpeg")
newImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)     ## converet bgrto rgb

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img)
plt.show()
plt.imshow(newImg)
plt.show()

# %%
print(img)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[106  99  84]
#   [ 88  81  66]
#   [ 80  73  58]
#   ...
#   [121 118 100]
#   [123 120 102]
#   [126 123 105]]
#
#  [[102  95  80]
#   [ 91  84  69]
#   [ 86  79  64]
#   ...
#   [117 114  96]
#   [120 117  99]
#   [125 122 104]]
#
#  [[ 92  85  70]
#   [ 91  84  69]
#   [ 92  85  70]
#   ...
#   [116 113  95]
#   [121 118 100]
#   [126 123 105]]]
